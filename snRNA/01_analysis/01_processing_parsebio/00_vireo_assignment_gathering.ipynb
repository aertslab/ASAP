# %% [markdown]
# # Notebook to gather Vireo assignment information

# %%
mkdir -p vireo_PB-001

# %%
for file in /20241004_patient_demultiplexing/vireo/parsebio/*001*/donor_ids.tsv # replace path as necessary
do 
    
    name=${file#/20241004_patient_demultiplexing/vireo/parsebio/}
    name=${name%/donor_ids.tsv}
    echo $name
    ln -s $file vireo_PB-001/$name.tsv
    printf "\n"
done
# Out:
# PB-001-pool_1
#
# PB-001-pool_2
#
# PB-001-pool_3

# %%
mkdir -p vireo_PB-002

# %%
for file in /20241004_patient_demultiplexing/vireo/parsebio/*002*/donor_ids.tsv
do 
    
    name=${file#/20241004_patient_demultiplexing/vireo/parsebio/}
    name=${name%/donor_ids.tsv}
    echo $name
    ln -s $file vireo_PB-002/$name.tsv
    printf "\n"
done
# Out:
# PB-002-pool_1
#
# PB-002-pool_10
#
# PB-002-pool_2
#
# PB-002-pool_3
#
# PB-002-pool_4
#
# PB-002-pool_5
#
# PB-002-pool_6
#
# PB-002-pool_7
#
# PB-002-pool_8
#
# PB-002-pool_9
