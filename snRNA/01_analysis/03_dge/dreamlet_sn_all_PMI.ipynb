# %%
library(dreamlet)
library(zenith)
library(scater)

# %% [markdown]
# # 01 Preprocess data

# %%
sce = schard::h5ad2sce('../02_combination_10x_pb/hdf5/20250221_all_data_integrated_filtered_umap_scANVI_metadata_ct_corrected.sn.h5ad') # change path as necessary

# %%
# check if X is counts or not; if it is rename to counts
if (all(assay(sce, "X") == floor(assay(sce, "X")))) {
  assayNames(sce)[assayNames(sce) == "X"] <- "counts"
  cat("Assay 'X' renamed to 'counts' (contains integer values)\n")
} else {
  cat("Assay 'X' are not counts; check your input\n")
}

# %%
sce

# %%
keep_cells <- !is.na(colData(sce)$vireo_assignment) & 
              colData(sce)$vireo_assignment != "unassigned" &
             !is.na(colData(sce)$primary_diagnosis)
sce <- sce[, keep_cells]

# %%
# keep only one batch per donor, in case donor present in both parsebio and 10x
meta <- as.data.frame(colData(sce))
meta$cell_id <- rownames(meta)  # Add cell barcodes as a column

# Find the batch with the most cells for each donor
keep_cells <- unlist(
  lapply(split(meta, meta$vireo_assignment), function(df) {
    tab <- table(df$batch)
    best_batch <- names(tab)[which.max(tab)]
    df$cell_id[df$batch == best_batch]
  })
)

# Subset the SCE object to keep only those cells
sce <- sce[, keep_cells]

# %%
# update primary diagnosis labels
colData(sce)$primary_diagnosis[colData(sce)$primary_diagnosis == "Other neurological disorder"] <- "Healthy Control"
colData(sce)$primary_diagnosis[colData(sce)$primary_diagnosis == "Healthy Control"] <- "Control"
colData(sce)$primary_diagnosis[colData(sce)$primary_diagnosis == "Idiopathic PD"] <- "PD"

# %%
# meta <- read.csv("/donor_statistics/crn_metadata/upload/CLINPATH.csv", stringsAsFactors = FALSE)


# colData(sce)$duration_PMI <- meta$duration_PMI[
#   match(colData(sce)$vireo_assignment, meta$subject_id)
# ]

# # Optional checks
# sum_na <- sum(is.na(colData(sce)$duration_PMI))

# %%
sce <- sce[rowSums(counts(sce) > 0) > 0, ]

# compute QC metrics
qc <- perCellQCMetrics(sce)

# remove cells with few or many detected genes
ol <- isOutlier(metric = qc$detected, nmads = 2, log = TRUE)
#sce <- sce[, !ol]

# set variable indicating PD  or control
sce$PD <- sce$primary_diagnosis

# %%
table(ol)

# %% [markdown]
# # 02 Aggregate to pseudobulk

# %%
sce$id <- paste0(sce$batch, sce$vireo_assignment)

pb <- aggregateToPseudoBulk(sce,
  assay = "counts",
  cluster_id = "cell_type_neuron_incl",
  sample_id = "id",
  verbose = FALSE
)

# one 'assay' per cell type
assayNames(pb)

# %%
pb

# %% [markdown]
# # 03 Voom for pseudobulk
#
# Apply voom-style normalization for pseudobulk counts within each cell cluster using voomWithDreamWeights to handle random effects (if specified).

# %%
colnames(pb)

# %%
pb

# %%
# add PMI information to colData(pb)
meta <- read.csv("/crn_metadata/upload/CLINPATH.csv", stringsAsFactors = FALSE) # adjust path as necessary


# Map duration_PMI onto colData(sce) using vireo_assignment -> subject_id
meta$subject_id <- trimws(as.character(meta$subject_id))
colData(pb)$vireo_assignment <- trimws(as.character(colData(pb)$vireo_assignment))

# Create index mapping from vireo_assignment to subject_id
idx <- match(colData(pb)$vireo_assignment, meta$subject_id)

# Map duration_PMI using the index
colData(pb)$duration_pmi <- meta$duration_pmi[idx]

# %%
colData(pb)

# %%
# Normalize and apply voom/voomWithDreamWeights
form = ~ age_at_collection + sex + biobank_name + batch + duration_pmi
res.proc <- processAssays(pb, form, min.count = 5, min.cells = 5)

# the resulting object of class dreamletProcessedData stores
# normalized data and other information
res.proc

# %%
# view details of dropping samples
details(res.proc)

# %%
details(res.proc)$n_genes

# %%
# show voom plot for each cell clusters
plotVoom(res.proc)

# %% [markdown]
# # 04 Variance partitioning

# %%
# run variance partitioning analysis
form <- ~ age_at_collection + sex + biobank_name + batch + duration_pmi + PD
vp.lst <- fitVarPart(res.proc, form)

# %%
# Show variance fractions at the gene-level for each cell type
genes <- vp.lst$gene[2:15]
plotPercentBars(vp.lst[vp.lst$gene %in% genes, ])

# %%
# Summarize variance fractions genome-wide for each cell type
options(repr.plot.width = 20, repr.plot.height = 20)
plotVarPart(vp.lst, label.angle = 60)

# %% [markdown]
# # 05 Differential expression

# %%
# Differential expression analysis within each assay,
# evaluated on the voom normalized data
form <- ~ age_at_collection + sex + biobank_name + batch + duration_pmi + PD
res.dl <- dreamlet(res.proc, form)

# names of estimated coefficients
coefNames(res.dl)

# %%
# the resulting object of class dreamletResult
# stores results and other information
res.dl

# %% [markdown]
# ## 051 Volcano plot
#
# Red is FDR < 0.05

# %%
plotVolcano(res.dl, coef = "PDPD")

# %%
library(dplyr)
topTable(res.dl, coef = "PDPD", number=Inf) %>% write.table(file="dreamlet/2026_fdp_ASAP_sn_all_bulk_PDPD.tsv", quote=FALSE, sep="\t", row.names=FALSE)

# %%
topTable(res.dl, coef = "PDPD", number = Inf) %>%
  as.data.frame() %>%
  filter(adj.P.Val <= 0.05) %>%
  count(assay)

# %%
sessionInfo()

# %% [markdown]
# ```
# class: SingleCellExperiment
# dim: 39502 376394
# metadata(0):
# assays(1): counts
# rownames(39502): A1BG-AS1 A1CF ... ZZEF1 ZZZ3
# rowData names(5): _index highly_variable means dispersions
#   dispersions_norm
# colnames(376394): 01_01_25__s1 01_03_88__s1 ... TTTGTTGCATTCAGGT-rn006a
#   TTTGTTGGTCGTCATA-rn006a
# colData names(57): _index age_at_collection ... predicted_doublet/mask
#   predicted_doublet/values
# reducedDimNames(5): X_pca X_scANVI X_scVI X_tsne X_umap
# mainExpName: NULL
# altExpNames(0):
# Warning message in .sparse2dense(e1):
# “sparse->dense coercion: allocating vector of size 110.8 GiB”
# Warning message in .sparse2dense(e2):
# “sparse->dense coercion: allocating vector of size 110.8 GiB”
# Assay 'X' renamed to 'counts' (contains integer values)
# Loading required package: variancePartition
#
# Loading required package: ggplot2
#
# Loading required package: limma
#
# Loading required package: BiocParallel
#
#
# Attaching package: ‘variancePartition’
#
#
# The following object is masked from ‘package:limma’:
#
#     topTable
#
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
# ...
#
#     plotMDS
#
#
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
#
# ol
#  FALSE   TRUE
# 320811  23972
# 'Astro''DopaN''Endo''GabaN''GlutaN''Micro-PVM''OPC''Oligo''immune''neurons_unk'
# class: SingleCellExperiment
# dim: 39047 137
# metadata(2): agg_pars aggr_means
# assays(10): Astro DopaN ... immune neurons_unk
# rownames(39047): A1BG-AS1 A1CF ... ZZEF1 ZZZ3
# rowData names(5): _index highly_variable means dispersions
#   dispersions_norm
# colnames(137): 10XASA_001 10XASA_007 ... PB-002ASA_169 PB-002ASA_170
# colData names(13): age_at_collection age_at_diagnosis ...
#   predicted_doublet/values PD
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):
# '10XASA_001''10XASA_007''10XASA_008''10XASA_009''10XASA_010''10XASA_011''10XASA_016''10XASA_017''10XASA_018''10XASA_019''10XASA_020''10XASA_021''10XASA_022''10XASA_024''10XASA_025''10XASA_026''10XASA_027''10XASA_029''10XASA_030''10XASA_037''10XASA_038''10XASA_039''10XASA_040''10XASA_041''10XASA_042''10XASA_043''10XASA_044''10XASA_045''10XASA_046''10XASA_048''10XASA_049''10XASA_050''10XASA_101''10XASA_102''10XASA_103''10XASA_104''10XASA_105''10XASA_106''10XASA_107''10XASA_108''10XASA_109''10XASA_110''10XASA_111''10XASA_112''10XASA_113''10XASA_114''10XASA_115''10XASA_116''10XASA_117''10XASA_118''10XASA_119''10XASA_120''10XASA_131''10XASA_132''10XASA_133''10XASA_134''10XASA_135''10XASA_136''10XASA_138''10XASA_139''10XASA_140''10XASA_141''10XASA_142''10XASA_143''10XASA_144''10XASA_145''10XASA_146''10XASA_147''10XASA_148''10XASA_149''10XASA_150''10XASA_151''10XASA_152''10XASA_153''10XASA_154''10XASA_155''10XASA_156''10XASA_157''10XASA_158''10XASA_159''10XASA_160''10XASA_171''10XASA_172''10XASA_173''10XASA_174''10XASA_175''10XASA_176''10XASA_177''10XASA_178''10XASA_179''10XASA_180''10XASA_181''10XASA_182''10XASA_183''10XASA_184''10XASA_185''10XASA_186''10XASA_187''10XASA_188''10XASA_189''10XASA_190''PB-002ASA_002''PB-002ASA_003''PB-002ASA_004''PB-002ASA_005''PB-002ASA_006''PB-002ASA_012''PB-002ASA_013''PB-002ASA_014''PB-002ASA_015''PB-002ASA_028''PB-002ASA_031''PB-002ASA_032''PB-002ASA_033''PB-002ASA_034''PB-002ASA_035''PB-002ASA_036''PB-002ASA_121''PB-002ASA_122''PB-002ASA_123''PB-002ASA_124''PB-002ASA_125''PB-002ASA_126''PB-002ASA_127''PB-002ASA_128''PB-002ASA_129''PB-002ASA_130''PB-002ASA_161''PB-002ASA_162''PB-002ASA_163''PB-002ASA_164''PB-002ASA_165''PB-002ASA_166''PB-002ASA_167''PB-002ASA_168''PB-002ASA_169''PB-002ASA_170'
# class: SingleCellExperiment
# dim: 39047 137
# metadata(2): agg_pars aggr_means
# assays(10): Astro DopaN ... immune neurons_unk
# rownames(39047): A1BG-AS1 A1CF ... ZZEF1 ZZZ3
# rowData names(5): _index highly_variable means dispersions
#   dispersions_norm
# colnames(137): 10XASA_001 10XASA_007 ... PB-002ASA_169 PB-002ASA_170
# colData names(13): age_at_collection age_at_diagnosis ...
#   predicted_doublet/values PD
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):
# DataFrame with 137 rows and 14 columns
#               age_at_collection age_at_diagnosis       batch biobank_name
#                       <numeric>        <numeric> <character>  <character>
# 10XASA_001                   57              NaN         10X Edinburgh_UK
# 10XASA_007                   46              NaN         10X Edinburgh_UK
# 10XASA_008                   46              NaN         10X Edinburgh_UK
# 10XASA_009                   57              NaN         10X Edinburgh_UK
# 10XASA_010                   34              NaN         10X Edinburgh_UK
# ...                         ...              ...         ...          ...
# PB-002ASA_166                89               75      PB-002      QSBB_UK
# PB-002ASA_167                87               73      PB-002      QSBB_UK
# PB-002ASA_168                92               76      PB-002      QSBB_UK
# PB-002ASA_169                72               61      PB-002      QSBB_UK
# PB-002ASA_170                93               80      PB-002      QSBB_UK
#                   outlier primary_diagnosis           region         sex
#               <character>       <character>      <character> <character>
# 10XASA_001          FALSE           Control Substantia Nigra        Male
# 10XASA_007          FALSE           Control Substantia Nigra      Female
# 10XASA_008          FALSE           Control Substantia Nigra        Male
# 10XASA_009          FALSE           Control Substantia Nigra      Female
# 10XASA_010          FALSE           Control Substantia Nigra        Male
# ...                   ...               ...              ...         ...
# PB-002ASA_166       FALSE                PD Substantia Nigra        Male
# PB-002ASA_167       FALSE                PD Substantia Nigra        Male
# PB-002ASA_168       FALSE                PD Substantia Nigra        Male
# ...
# PB-002ASA_166                    FALSE          PD        39.40
# PB-002ASA_167                    FALSE          PD       103.07
# PB-002ASA_168                    FALSE          PD        41.35
# PB-002ASA_169                    FALSE          PD        51.00
# PB-002ASA_170                    FALSE          PD        82.20
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
#   Astro...
# 7 secs
#
#   DopaN...
# 2.9 secs
#
#   Endo...
# 1.9 secs
#
#   GabaN...
# 4.1 secs
#
#   GlutaN...
# 3.4 secs
#
#   Micro-PVM...
# 4.3 secs
#
#   OPC...
# 4.9 secs
#
#   Oligo...
# 6.5 secs
#
#   immune...
# ...
#
#   neurons_unk...
# 1.7 secs
#
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
# class: dreamletProcessedData
# assays(10): Astro DopaN ... immune neurons_unk
# colData(14): age_at_collection age_at_diagnosis ... PD duration_pmi
# metadata(33): cell_type_neuron_incl id ... total_counts_ribo tscp_count
# Samples:
#  min: 84
#  max: 131
# Genes:
#  min: 1412
#  max: 14765
# details(7): assay n_retain ... n_errors error_initial
# A data.frame: 10 × 7
# assay	n_retain	formula	formDropsTerms	n_genes	n_errors	error_initial
# <chr>	<int>	<chr>	<lgl>	<int>	<int>	<lgl>
# Astro	129	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	14079	0	FALSE
# DopaN	84	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	8809	0	FALSE
# Endo	112	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	3365	0	FALSE
# GabaN	123	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	9616	0	FALSE
# GlutaN	95	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	8345	0	FALSE
# Micro-PVM	124	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	11043	0	FALSE
# OPC	131	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	11353	0	FALSE
# Oligo	129	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	14765	0	FALSE
# immune	89	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	1412	0	FALSE
# neurons_unk	88	~age_at_collection + sex + biobank_name + batch + duration_pmi	FALSE	4420	0	FALSE
# 14079880933659616834511043113531476514124420
#   Astro...
# 54 secs
#
#   DopaN...
# 33 secs
#
#   Endo...
# 12 secs
#
#   GabaN...
# 35 secs
#
#   GlutaN...
# 29 secs
#
#   Micro-PVM...
# 40 secs
#
#   OPC...
# 39 secs
#
#   Oligo...
# 53 secs
#
#   immune...
# ...
#
#
#
#
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
# Warning message in geom_boxplot(aes(outlier.colour = factor(variable)), width = 0.07, :
# “Ignoring unknown aesthetics: outlier.colour”
#   Astro...
# 3.1 secs
#
#   DopaN...
# 1.5 secs
#
#   Endo...
# 0.68 secs
#
#   GabaN...
# 1.8 secs
#
#   GlutaN...
# 1.6 secs
#
#   Micro-PVM...
# 2.2 secs
#
#   OPC...
# 2.2 secs
#
#   Oligo...
# 2.9 secs
#
#   immune...
# ...
#
#   neurons_unk...
# 0.81 secs
#
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
# '(Intercept)''age_at_collection''sexMale''biobank_nameQSBB_UK''batchPB-002''duration_pmi''PDPD'
# class: dreamletResult
# assays(10): Astro DopaN ... immune neurons_unk
# Genes:
#  min: 1412
#  max: 14765
# details(7): assay n_retain ... n_errors error_initial
# coefNames(7): (Intercept) age_at_collection ... duration_pmi PDPD
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_text_repel()`).”
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
# ...
#
#     intersect, setdiff, setequal, union
#
#
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
# A data.frame: 10 × 2
# assay	n
# <chr>	<int>
# Astro	106
# DopaN	22
# Endo	2
# GabaN	6
# GlutaN	12
# Micro-PVM	43
# OPC	62
# Oligo	72
# immune	5
# neurons_unk	1
# R version 4.4.3 (2025-02-28)
# Platform: x86_64-conda-linux-gnu
# Running under: Rocky Linux 9.6 (Blue Onyx)
#
# Matrix products: default
# BLAS/LAPACK: /envs/dreamlet/lib/libopenblasp-r0.3.30.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.utf8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.utf8        LC_COLLATE=C
#  [5] LC_MONETARY=en_US.utf8    LC_MESSAGES=en_US.utf8
#  [7] LC_PAPER=en_US.utf8       LC_NAME=C
#  [9] LC_ADDRESS=C              LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.utf8 LC_IDENTIFICATION=C
#
# time zone: Europe/Brussels
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] GO.db_3.20.0                org.Hs.eg.db_3.20.0
#  [3] AnnotationDbi_1.68.0        dplyr_1.1.4
#  [5] scater_1.34.1               scuttle_1.16.0
#  [7] zenith_1.8.0                dreamlet_1.6.0
#  [9] SingleCellExperiment_1.28.0 SummarizedExperiment_1.36.0
# [11] Biobase_2.66.0              GenomicRanges_1.58.0
# [13] GenomeInfoDb_1.42.0         IRanges_2.40.0
# [15] S4Vectors_0.44.0            BiocGenerics_0.52.0
# [17] MatrixGenerics_1.18.0       matrixStats_1.5.0
# [19] variancePartition_1.36.2    BiocParallel_1.40.0
# [21] limma_3.62.1                ggplot2_3.5.2
#
# loaded via a namespace (and not attached):
#   [1] splines_4.4.3             pbdZMQ_0.3-14
#   [3] filelock_1.0.3            bitops_1.0-9
#   [5] tibble_3.3.0              graph_1.84.0
#   [7] XML_3.99-0.17             lifecycle_1.0.4
#   [9] Rdpack_2.6.4              mixsqp_0.3-54
#  [11] edgeR_4.4.0               lattice_0.22-7
#  [13] MASS_7.3-64               backports_1.5.0
#  [15] magrittr_2.0.3            metafor_4.8-0
#  [17] DBI_1.2.3                 minqa_1.2.8
#  [19] RColorBrewer_1.1-3        abind_1.4-5
#  [21] zlibbioc_1.52.0           EnvStats_3.1.0
#  [23] purrr_1.1.0               rmeta_3.0
#  [25] msigdbr_25.1.1            RCurl_1.98-1.17
#  [27] GenomeInfoDbData_1.2.13   ggrepel_0.9.6
#  [29] pbkrtest_0.5.5            irlba_2.3.5.1
#  [31] annotate_1.84.0           DelayedMatrixStats_1.28.0
#  [33] codetools_0.2-20          DelayedArray_0.32.0
#  [35] tidyselect_1.2.1          UCSC.utils_1.2.0
#  [37] farver_2.1.2              viridis_0.6.5
#  [39] ScaledMatrix_1.14.0       lme4_1.1-37
#  [41] BiocFileCache_2.14.0      base64enc_0.1-3
#  [43] mathjaxr_1.8-0            jsonlite_2.0.0
#  [45] BiocNeighbors_2.0.0       iterators_1.0.14
#  [47] systemfonts_1.2.3         tools_4.4.3
#  [49] progress_1.2.3            ragg_1.4.0
#  [51] Rcpp_1.1.0                glue_1.8.0
#  [53] gridExtra_2.3             SparseArray_1.6.0
#  [55] IRdisplay_1.1             schard_0.0.1
#  [57] withr_3.0.2               numDeriv_2016.8-1.1
#  [59] fastmap_1.2.0             rhdf5filters_1.18.0
#  [61] boot_1.3-31               rsvd_1.0.5
#  [63] caTools_1.18.3            digest_0.6.37
#  [65] truncnorm_1.0-9           R6_2.6.1
#  [67] textshaping_1.0.1         colorspace_2.1-1
#  [69] Cairo_1.6-2               scattermore_1.2
#  [71] gtools_3.9.5              RSQLite_2.4.2
#  [73] RhpcBLASctl_0.23-42       tidyr_1.3.1
#  [75] generics_0.1.4            data.table_1.17.8
#  [77] corpcor_1.6.10            prettyunits_1.2.0
#  [79] httr_1.4.7                S4Arrays_1.6.0
#  [81] pkgconfig_2.0.3           gtable_0.3.6
#  [83] blob_1.2.4                XVector_0.46.0
#  [85] remaCor_0.0.18            htmltools_0.5.8.1
#  [87] GSEABase_1.68.0           scales_1.4.0
#  [89] png_0.1-8                 fANCOVA_0.6-1
#  [91] reformulas_0.4.1          ashr_2.2-63
#  [93] reshape2_1.4.4            uuid_1.2-1
#  [95] nlme_3.1-168              curl_6.4.0
#  [97] nloptr_2.2.1              rhdf5_2.50.0
#  [99] repr_1.1.7                cachem_1.1.0
# [101] stringr_1.5.1             KernSmooth_2.23-26
# [103] parallel_4.4.3            vipor_0.4.7
# [105] metadat_1.4-0             RcppZiggurat_0.1.8
# [107] pillar_1.11.0             grid_4.4.3
# [109] vctrs_0.6.5               gplots_3.2.0
# [111] BiocSingular_1.22.0       dbplyr_2.5.0
# [113] beachmat_2.22.0           mashr_0.2.79
# [115] xtable_1.8-4              beeswarm_0.4.0
# [117] Rgraphviz_2.50.0          evaluate_1.0.4
# [119] KEGGgraph_1.66.0          invgamma_1.2
# [121] mvtnorm_1.3-3             cli_3.6.5
# [123] locfit_1.5-9.12           compiler_4.4.3
# [125] rlang_1.1.6               crayon_1.5.3
# [127] SQUAREM_2021.1            labeling_0.4.3
# [129] plyr_1.8.9                ggbeeswarm_0.7.2
# [131] stringi_1.8.7             viridisLite_0.4.2
# [133] assertthat_0.2.1          babelgene_22.9
# [135] lmerTest_3.1-3            Biostrings_2.74.0
# [137] aod_1.3.3                 Matrix_1.7-3
# [139] IRkernel_1.3.2            hms_1.1.3
# [141] sparseMatrixStats_1.18.0  bit64_4.6.0-1
# [143] Rhdf5lib_1.28.0           KEGGREST_1.46.0
# [145] statmod_1.5.0             rbibutils_2.3
# [147] Rfast_2.1.0               broom_1.0.9
# [149] memoise_2.0.1             RcppParallel_5.1.9
# [151] bit_4.6.0                 EnrichmentBrowser_2.36.0
# ```
